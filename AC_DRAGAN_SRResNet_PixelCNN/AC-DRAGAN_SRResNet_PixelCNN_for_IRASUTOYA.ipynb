# %%
import tensorflow as tf
import os
import numpy as np

model_name = "AC-DRAGAN_SRResNet_PixelCNN_for_IRASUTOYA"

# %%
from model import *
from utility import *

# %%
class Generator:
    def __init__(self):
        self.reuse = False
        self.g_bn0 = BatchNormalization(name = 'g_bn0')

        self.num_res_blocks = 16
        self.num_pixel_CNN_blocks = 3
        
        self.res_bns = []
        for i in range(int(self.num_res_blocks)):
            self.res_bns.append(BatchNormalization(name = "res_%d" % (2*i)))
            self.res_bns.append(BatchNormalization(name = "res_%d" % (2*i+1)))
        
        self.ps_bns = []
        for i in range(int(self.num_pixel_CNN_blocks)):
            self.ps_bns.append(BatchNormalization(name = "ps_%d" % i))
        
        self.g_bn1 = BatchNormalization(name = 'g_bn1')
        
    def __call__(self, z):
        with tf.variable_scope('g', reuse=self.reuse):
            
            # reshape from inputs
            with tf.variable_scope('fc0'):
                #z0 = tf.reshape(z, [-1, self.z_dim])
                fc0 = full_connection_layer(z, 64*16*16, name="fc0")
                fc0 = self.g_bn0(fc0)
                fc0 = tf.nn.relu(fc0)
                fc0 = tf.reshape(fc0, [-1,16,16,64])

            assert fc0.get_shape().as_list()[1:] == [16,16,64]
            
            layers = []
            layers.append(fc0)
            
            for i in range(int(self.num_res_blocks)):
                with tf.variable_scope('res_%d' % (i+1)):
                    res = conv2d_layer(layers[-1], 64, kernel_size=3, strides=1, name="g_conv_res_%d" % (2*i))
                    res = self.res_bns[2*i](res)
                    res = tf.nn.relu(res)

                    res = conv2d_layer(res, 64, kernel_size=3, strides=1, name="g_conv_res_%d" % (2*i+1))
                    res = self.res_bns[2*i+1](res)
                    res = layers[-1] + res
                    layers.append(res)                    

            assert layers[-1].get_shape().as_list()[1:] == [16,16,64]
            
            with tf.variable_scope('conv17'):
                conv17 = conv2d_layer(layers[-1], 64, kernel_size=3, strides=1, name="g_conv_17")
                conv17 = self.g_bn1(conv17)
                conv17 = tf.nn.relu(conv17)
                conv17 = layers[0] + conv17
                layers.append(conv17)

            assert layers[-1].get_shape().as_list()[1:] == [16, 16, 64]

            for i in range(int(self.num_pixel_CNN_blocks)):
                with tf.variable_scope('pixel_CNN_%d' % (i+1)):
                    ps = conv2d_layer(layers[-1], 256, kernel_size=3, strides=1, name="g_conv_ps_%d" % (i))
                    ps = pixel_shuffle_layer(ps, 2, 64)
                    ps = self.ps_bns[i](ps)
                    ps = tf.nn.relu(ps)
                    layers.append(ps)

            assert layers[-1].get_shape().as_list()[1:] == [128, 128, 64]
                    
            with tf.variable_scope('output'):
                output = conv2d_layer(layers[-1], 3, kernel_size=9, strides=1, name="output")
                output = tf.nn.sigmoid(output)

            assert output.get_shape().as_list()[1:] == [128, 128, 3]            
            
        self.reuse = True
        self.variables = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='g')
        return output

# %%
class Discriminator:
    def __init__(self, cat_size):
        self.reuse = False
        self.d_bn0 = BatchNormalization(name="d_bn0")
        self.d_bn1 = BatchNormalization(name="d_bn1")
        self.d_bn2 = BatchNormalization(name="d_bn2")
        self.d_bn3 = BatchNormalization(name="d_bn3")
        self.d_bn4 = BatchNormalization(name="d_bn4")
        
        self.cat_size = cat_size

    def __call__(self, x):
        def leaky_relu(x):
            return lrelu(x, leak=0.2)

        with tf.variable_scope('d', reuse=self.reuse):
           
            x = tf.reshape(x, [-1, 128, 128, 3])
            with tf.variable_scope('conv1'):
                conv1 = tf.layers.conv2d(x, 32, [4, 4], [2 ,2], padding="SAME", kernel_initializer=tf.truncated_normal_initializer(0.0, 0.02))
                conv1 = leaky_relu(conv1)

            with tf.variable_scope('res1'):
                res1 = tf.layers.conv2d(conv1, 32, [3,3], [1,1], padding="SAME", kernel_initializer=tf.truncated_normal_initializer(0.0, 0.02))
                res1 = leaky_relu(res1)
                res1 = tf.layers.conv2d(res1, 32, [3,3], [1,1], padding="SAME", kernel_initializer=tf.truncated_normal_initializer(0.0, 0.02))
                res1 = res1 + conv1
                res1 = leaky_relu(res1)

            with tf.variable_scope('res2'):
                res2 = tf.layers.conv2d(res1, 32, [3,3], [1,1], padding="SAME", kernel_initializer=tf.truncated_normal_initializer(0.0, 0.02))
                res2 = leaky_relu(res2)
                res2 = tf.layers.conv2d(res2, 32, [3,3], [1,1], padding="SAME", kernel_initializer=tf.truncated_normal_initializer(0.0, 0.02))
                res2 = res2 + res1
                res2 = leaky_relu(res2)

            with tf.variable_scope('conv2'):
                conv2 = tf.layers.conv2d(res2, 64, [4, 4], [2 ,2], padding="SAME", kernel_initializer=tf.truncated_normal_initializer(0.0, 0.02))
                conv2 = leaky_relu(conv2)

            with tf.variable_scope('res3'):
                res3 = tf.layers.conv2d(conv2, 64, [3,3], [1,1], padding="SAME", kernel_initializer=tf.truncated_normal_initializer(0.0, 0.02))
                res3 = leaky_relu(res3)
                res3 = tf.layers.conv2d(res3, 64, [3,3], [1,1], padding="SAME", kernel_initializer=tf.truncated_normal_initializer(0.0, 0.02))
                res3 = leaky_relu(res3)
                res3 = res3 + conv2
                res3 = leaky_relu(res3)

            with tf.variable_scope('res4'):
                res4 = tf.layers.conv2d(res3, 64, [3,3], [1,1], padding="SAME", kernel_initializer=tf.truncated_normal_initializer(0.0, 0.02))
                res4 = leaky_relu(res4)
                res4 = tf.layers.conv2d(res4, 64, [3,3], [1,1], padding="SAME", kernel_initializer=tf.truncated_normal_initializer(0.0, 0.02))
                res4 = leaky_relu(res4)
                res4 = res4 + res3
                res4 = leaky_relu(res4)

            with tf.variable_scope('conv3'):
                conv3 = tf.layers.conv2d(res4, 128, [4, 4], [2 ,2], padding="SAME", kernel_initializer=tf.truncated_normal_initializer(0.0, 0.02))
                conv3 = leaky_relu(conv3)

            num_res_itr = 3
            layers = []
            layers.append(conv3)
            
            depth = [128, 256, 512, 1024]
            for i in range(int(num_res_itr)):
                with tf.variable_scope('res_%d_1' % (i+1+4)):
                    res = tf.layers.conv2d(layers[-1], depth[i], [3,3], [1,1], padding="SAME", kernel_initializer=tf.truncated_normal_initializer(0.0, 0.02))
                    res = leaky_relu(res)
                    res = tf.layers.conv2d(res, depth[i], [3,3], [1,1], padding="SAME", kernel_initializer=tf.truncated_normal_initializer(0.0, 0.02))
                    res = leaky_relu(res)
                    res = layers[-1] + res
                    res = leaky_relu(res)
                layers.append(res)

                with tf.variable_scope('res_%d_2' % (i+1+4)):
                    res = tf.layers.conv2d(layers[-1], depth[i], [3,3], [1,1], padding="SAME", kernel_initializer=tf.truncated_normal_initializer(0.0, 0.02))
                    res = leaky_relu(res)
                    res = tf.layers.conv2d(res, depth[i], [3,3], [1,1], padding="SAME", kernel_initializer=tf.truncated_normal_initializer(0.0, 0.02))
                    res = leaky_relu(res)
                    res = layers[-1] + res
                    res = leaky_relu(res)

                conv = tf.layers.conv2d(res, depth[i+1], [4, 4], [2 ,2], padding="SAME", kernel_initializer=tf.truncated_normal_initializer(0.0, 0.02))
                conv = leaky_relu(conv) 
                layers.append(conv)

            disc = full_connection_layer(layers[-1], 1, name="disc")
            aux = full_connection_layer(layers[-1], self.cat_size, name="aux")

        self.reuse = True
        self.variables = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='d')

        return disc, aux

# %%
class GAN:
    def __init__(self):
        self.batch_size = 64
        self.img_size = 128
        self.rand_size = 100
        self.cat_size = 4
        self.z_size = self.rand_size + self.cat_size
        
        self.epochs = 50000
        self.epoch_saveMetrics = 100
        self.epoch_saveSampleImg = 100
        self.epoch_saveParamter = 5000
        self.losses = {"d_loss":[], "g_loss":[]}

        # unrolled counts
        self.steps = 5

        self.X_tr = tf.placeholder(tf.float32, shape=[None, self.img_size*self.img_size*3])
        self.Y_tr = tf.placeholder(tf.float32, shape=[None, self.cat_size])
        self.z = tf.placeholder(tf.float32, [None, self.z_size])
        self.X_per = tf.placeholder(tf.float32, shape=[None, self.img_size*self.img_size*3])

        self.g = Generator()
        self.d = Discriminator(self.cat_size)
        self.Xg = self.g(self.z)
        #self.dtd = DTD()
        self.irasutoya = IRASUTOYA()
        self.learning_rate = tf.placeholder("float", [])

    def loss(self):
        disc_tr, aux_tr = self.d(self.X_tr)
        disc_gen, aux_gen = self.d(self.Xg)
        
        lambda_adv = 1
        lambda_gp = 10
        lambda_c = 1
       
        loss_g = lambda_adv*tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_gen, labels=tf.ones_like(disc_gen)))
        #loss_g = lambda_adv*tf.reduce_mean(1 - tf.log(disc_gen + TINY))

        diff = self.X_per - self.X_tr
        #print(g_outputs.shape[0])
        alpha = tf.random_uniform(shape=[self.batch_size,1], minval=0., maxval=1.)
        interpolates = self.X_tr + (alpha*diff)
        disc_interplates, _ = self.d(interpolates)
        gradients = tf.gradients(disc_interplates, [interpolates])[0]
        slopes = tf.sqrt(tf.reduce_sum(tf.square(gradients), reduction_indices=[1]))
        gradient_penalty = tf.reduce_mean((slopes-1.)**2)

        loss_d_tr = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_tr, labels=tf.ones_like(disc_tr)))
        loss_d_gen = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_gen, labels=tf.zeros_like(disc_gen)))
        loss_d = lambda_adv*(loss_d_tr + loss_d_gen)
        loss_d += lambda_gp*gradient_penalty

        loss_c_tr = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=aux_tr, labels=self.Y_tr))
        loss_c_gen = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=aux_gen, labels=self.Y_tr))
        loss_c = (loss_c_tr + loss_c_gen)

        loss_g += loss_c
        loss_d += loss_c
        return loss_g, loss_d

    def train(self):
        # Optimizer
        d_lr = 1e-4
        d_beta1 = 0.5
        g_lr = 1e-4
        g_beta1 = 0.5

        self.L_g, self.L_d = self.loss()

        d_opt = tf.train.AdamOptimizer(learning_rate=self.learning_rate)
        d_train_op = d_opt.minimize(self.L_d, var_list=self.d.variables)
        g_opt = tf.train.AdamOptimizer(learning_rate=self.learning_rate)
        g_train_op = g_opt.minimize(self.L_g, var_list=self.g.variables)

        saver = tf.train.Saver()
        
        config = tf.ConfigProto(
            gpu_options=tf.GPUOptions(
                visible_device_list= "0"
            )
        )
                
        with tf.Session(config=config) as sess:
            sess.run(tf.global_variables_initializer())

            # preparing noise vec for test
            bs = 100
            test_z = np.random.uniform(-1, 1, size=[bs, self.z_size])

            # cat 0
            bs = 10
            test_cat0_rand = np.random.uniform(-1, 1, size=[bs, self.rand_size])
            test_cat0_cat = np.zeros([bs, self.cat_size])
            test_cat0_cat[:, 0] = np.linspace(-1, 1, num=bs)
            test_cat0_z = np.concatenate((test_cat0_rand, test_cat0_cat), axis=1)  

            # cat 1
            bs = 10
            #test_cat1_rand = np.random.uniform(-1, 1, size=[bs, self.rand_size])
            test_cat1_cat = np.zeros([bs, self.cat_size])
            test_cat1_cat[:, 1] = np.linspace(-1, 1, num=bs)
            test_cat1_z = np.concatenate((test_cat0_rand, test_cat1_cat), axis=1)  

            # cat 2
            bs = 10
            #test_cat1_rand = np.random.uniform(-1, 1, size=[bs, self.rand_size])
            test_cat2_cat = np.zeros([bs, self.cat_size])
            test_cat2_cat[:, 1] = np.linspace(-1, 1, num=bs)
            test_cat2_z = np.concatenate((test_cat0_rand, test_cat2_cat), axis=1)

            # cat 3
            bs = 10
            #test_cat1_rand = np.random.uniform(-1, 1, size=[bs, self.rand_size])
            test_cat3_cat = np.zeros([bs, self.cat_size])
            test_cat3_cat[:, 1] = np.linspace(-1, 1, num=bs)
            test_cat3_z = np.concatenate((test_cat0_rand, test_cat3_cat), axis=1)

            lr = 1e-4
            for epoch in range(self.epochs):
                if epoch > 2000:
                    lr = 5e-5
                if epoch > 4000:
                    lr = 1e-5

                # visualize generated images during training
                if epoch % self.epoch_saveSampleImg == 0:
                    # rand
                    img = sess.run(self.Xg, feed_dict={self.z: test_z})
                    save_imgs(model_name, img, name=str(epoch)+"_rand")

                    # cat
                    test_cat = np.concatenate((test_cat0_z, test_cat1_z, test_cat2_z, test_cat3_z), axis=0)
                    img = sess.run(self.Xg, feed_dict={self.z: test_cat})
                    save_imgs(model_name, img, plot_dim=(4,10), size=(20, 8), name=str(epoch)+"_cat")

                for step in range(self.steps):
                    # extract images for training
                    #rand_index = np.random.randint(0, self.dataset.shape[0], size=self.batch_size)
                    #X_mb, Y_mb = self.dataset[rand_index, :].astype(np.float32)
                    X_mb, Y_mb = self.irasutoya.extract(self.batch_size, self.img_size)
                    X_mb = np.reshape(X_mb, [self.batch_size, -1])
                    X_mb_per = X_mb + 0.5*np.std(X_mb)*np.random.random(X_mb.shape)

                    rand = np.random.uniform(-1, 1, size=[self.batch_size, self.rand_size])
                    #print(rand.shape)
                    #print(Y_mb.shape)
                    z = np.hstack((rand, Y_mb))
                    #print(z.shape)

                    # train Discriminator
                    _, d_loss_value = sess.run([d_train_op, self.L_d], feed_dict={
                        self.X_tr: X_mb,
                        self.z:z,
                        self.Y_tr: Y_mb,
                        self.X_per: X_mb_per,
                        self.learning_rate:lr,
                    })

                # train Generator
                _, g_loss_value = sess.run([g_train_op, self.L_g], feed_dict={
                    self.X_tr: X_mb,
                    self.z:z,
                    self.Y_tr: Y_mb,
                    self.X_per: X_mb_per,
                    self.learning_rate:lr,
                })

                # append loss value for visualizing
                self.losses["d_loss"].append(np.sum(d_loss_value))
                self.losses["g_loss"].append(np.sum(g_loss_value))
                
                # print epoch
                if epoch % 1 == 0:
                    print('epoch:{0}, d_loss:{1}, g_loss: {2} '.format(epoch, d_loss_value, g_loss_value))
                
                # visualize loss
                if epoch % self.epoch_saveMetrics == 0:
                    save_metrics(model_name, self.losses, epoch)


                # save model parameters 
                if epoch % self.epoch_saveParamter == 0:
                    dir_path = "model_" + model_name
                    if not os.path.isdir(dir_path):
                        os.makedirs(dir_path)

                    saver.save(sess, dir_path + "/" + str(epoch) + ".ckpt")

# %%
gan = GAN()
gan.train()
# Out:
# init IRASUTOYA
# 1839
# /home/ujitoko/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:81: DeprecationWarning: PyUnicode_AsEncodedObject() is deprecated; use PyUnicode_AsEncodedString() to encode from str to bytes or PyCodec_Encode() for generic encoding
# 1701.npy
# ./test001.png    ./test782.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1700, dtype: object
# 0162.npy
# ./test001.png    ./test163.png
# -1                          -1
# -1.1                         1
# -1.2                        -1
# -1.3                        -1
# Name: 161, dtype: object
# 0938.npy
# ./test001.png    ./test019.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 937, dtype: object
# 0633.npy
# ./test001.png    ./test634.png
# -1                           1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 632, dtype: object
# 0841.npy
# ./test001.png    ./test842.png
# -1                          -1
# -1.1                         1
# -1.2                        -1
# -1.3                        -1
# Name: 840, dtype: object
# 0032.npy
# ./test001.png    ./test033.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 31, dtype: object
# 0165.npy
# ./test001.png    ./test166.png
# -1                          -1
# -1.1                         1
# -1.2                        -1
# -1.3                        -1
# Name: 164, dtype: object
# 0263.npy
# ./test001.png    ./test264.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 262, dtype: object
# 1389.npy
# ./test001.png    ./test470.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1388, dtype: object
# 0814.npy
# ./test001.png    ./test815.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 813, dtype: object
# 0604.npy
# ./test001.png    ./test605.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 603, dtype: object
# 1313.npy
# ./test001.png    ./test394.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1312, dtype: object
# 0179.npy
# ./test001.png    ./test180.png
# -1                          -1
# -1.1                         1
# -1.2                        -1
# -1.3                        -1
# Name: 178, dtype: object
# 0277.npy
# ./test001.png    ./test278.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 276, dtype: object
# 0675.npy
# ./test001.png    ./test676.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 674, dtype: object
# 0867.npy
# ./test001.png    ./test868.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 866, dtype: object
# 1248.npy
# ./test001.png    ./test329.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 1247, dtype: object
# 1190.npy
# ./test001.png    ./test271.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1189, dtype: object
# 1676.npy
# ./test001.png    ./test757.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1675, dtype: object
# 0852.npy
# ./test001.png    ./test853.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 851, dtype: object
# 0896.npy
# ./test001.png    ./test897.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 895, dtype: object
# 1426.npy
# ./test001.png    ./test507.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1425, dtype: object
# 0838.npy
# ./test001.png    ./test839.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 837, dtype: object
# 1023.npy
# ./test001.png    ./test104.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 1022, dtype: object
# 1083.npy
# ./test001.png    ./test164.png
# -1                          -1
# -1.1                         1
# -1.2                        -1
# -1.3                        -1
# Name: 1082, dtype: object
# 0399.npy
# ./test001.png    ./test400.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 398, dtype: object
# 1242.npy
# ./test001.png    ./test323.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 1241, dtype: object
# 1522.npy
# ./test001.png    ./test603.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 1521, dtype: object
# 0259.npy
# ./test001.png    ./test260.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 258, dtype: object
# 1768.npy
# ./test001.png    ./test849.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1767, dtype: object
# 1436.npy
# ./test001.png    ./test517.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1435, dtype: object
# 0204.npy
# ./test001.png    ./test205.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 203, dtype: object
# 0358.npy
# ./test001.png    ./test359.png
# -1                           1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 357, dtype: object
# 0640.npy
# ./test001.png    ./test641.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 639, dtype: object
# 0308.npy
# ./test001.png    ./test309.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 307, dtype: object
# 1156.npy
# ./test001.png    ./test237.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1155, dtype: object
# 0937.npy
# ./test001.png    ./test018.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 936, dtype: object
# 0405.npy
# ./test001.png    ./test406.png
# -1                           1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 404, dtype: object
# 0053.npy
# ./test001.png    ./test054.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 52, dtype: object
# 0483.npy
# ./test001.png    ./test484.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 482, dtype: object
# 1529.npy
# ./test001.png    ./test610.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1528, dtype: object
# 1230.npy
# ./test001.png    ./test311.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1229, dtype: object
# 1719.npy
# ./test001.png    ./test800.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1718, dtype: object
# 0651.npy
# ./test001.png    ./test652.png
# -1                           1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 650, dtype: object
# 1185.npy
# ./test001.png    ./test266.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1184, dtype: object
# 1675.npy
# ./test001.png    ./test756.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1674, dtype: object
# 1275.npy
# ./test001.png    ./test356.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 1274, dtype: object
# 0140.npy
# ./test001.png    ./test141.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 139, dtype: object
# 0285.npy
# ./test001.png    ./test286.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 284, dtype: object
# 0659.npy
# ./test001.png    ./test660.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 658, dtype: object
# 1568.npy
# ./test001.png    ./test649.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1567, dtype: object
# 1809.npy
# ./test001.png    ./test890.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1808, dtype: object
# 0767.npy
# ./test001.png    ./test768.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 766, dtype: object
# 0766.npy
# ./test001.png    ./test767.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 765, dtype: object
# 1122.npy
# ./test001.png    ./test203.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1121, dtype: object
# 1011.npy
# ./test001.png    ./test092.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1010, dtype: object
# 0132.npy
# ./test001.png    ./test133.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 131, dtype: object
# 1061.npy
# ./test001.png    ./test142.png
# -1                           1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1060, dtype: object
# 0473.npy
# ./test001.png    ./test474.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 472, dtype: object
# 0543.npy
# ./test001.png    ./test544.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 542, dtype: object
# 0795.npy
# ./test001.png    ./test796.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 794, dtype: object
# 0824.npy
# ./test001.png    ./test825.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 823, dtype: object
# 1394.npy
# ./test001.png    ./test475.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1393, dtype: object
# 0772.npy
# ./test001.png    ./test773.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 771, dtype: object
# 0828.npy
# ./test001.png    ./test829.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 827, dtype: object
# 0856.npy
# ./test001.png    ./test857.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 855, dtype: object
# 0431.npy
# ./test001.png    ./test432.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 430, dtype: object
# 0576.npy
# ./test001.png    ./test577.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 575, dtype: object
# 0225.npy
# ./test001.png    ./test226.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 224, dtype: object
# 0260.npy
# ./test001.png    ./test261.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 259, dtype: object
# 1521.npy
# ./test001.png    ./test602.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1520, dtype: object
# 1473.npy
# ./test001.png    ./test554.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 1472, dtype: object
# 1413.npy
# ./test001.png    ./test494.png
# -1                          -1
# -1.1                         1
# -1.2                        -1
# -1.3                        -1
# Name: 1412, dtype: object
# 1695.npy
# ./test001.png    ./test776.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1694, dtype: object
# 0160.npy
# ./test001.png    ./test161.png
# -1                          -1
# -1.1                         1
# -1.2                         1
# -1.3                        -1
# Name: 159, dtype: object
# 0656.npy
# ./test001.png    ./test657.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 655, dtype: object
# 0470.npy
# ./test001.png    ./test471.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 469, dtype: object
# 0114.npy
# ./test001.png    ./test115.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 113, dtype: object
# 0286.npy
# ./test001.png    ./test287.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 285, dtype: object
# 1764.npy
# ./test001.png    ./test845.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1763, dtype: object
# epoch:0, d_loss:-0.5430402755737305, g_loss: -25.608306884765625
# 1240.npy
# ./test001.png    ./test321.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 1239, dtype: object
# 0426.npy
# ./test001.png    ./test427.png
# -1                          -1
# -1.1                         1
# -1.2                        -1
# -1.3                        -1
# Name: 425, dtype: object
# 1208.npy
# ./test001.png    ./test289.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1207, dtype: object
# 1704.npy
# ./test001.png    ./test785.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1703, dtype: object
# 0634.npy
# ./test001.png    ./test635.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 633, dtype: object
# 1351.npy
# ./test001.png    ./test432.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1350, dtype: object
# 0054.npy
# ./test001.png    ./test055.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 53, dtype: object
# 1460.npy
# ./test001.png    ./test541.png
# -1                           1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1459, dtype: object
# 0645.npy
# ./test001.png    ./test646.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 644, dtype: object
# 1810.npy
# ./test001.png    ./test891.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1809, dtype: object
# 1251.npy
# ./test001.png    ./test332.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 1250, dtype: object
# 0290.npy
# ./test001.png    ./test291.png
# -1                          -1
# -1.1                         1
# -1.2                         1
# -1.3                        -1
# Name: 289, dtype: object
# 0433.npy
# ./test001.png    ./test434.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 432, dtype: object
# 1727.npy
# ./test001.png    ./test808.png
# -1                          -1
# -1.1                         1
# -1.2                         1
# -1.3                        -1
# Name: 1726, dtype: object
# 1472.npy
# ./test001.png    ./test553.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1471, dtype: object
# 0771.npy
# ./test001.png    ./test772.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 770, dtype: object
# 1141.npy
# ./test001.png    ./test222.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1140, dtype: object
# 0935.npy
# ./test001.png    ./test016.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 934, dtype: object
# 0092.npy
# ./test001.png    ./test093.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 91, dtype: object
# 1460.npy
# ./test001.png    ./test541.png
# -1                           1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1459, dtype: object
# 0310.npy
# ./test001.png    ./test311.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 309, dtype: object
# 0623.npy
# ./test001.png    ./test624.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 622, dtype: object
# 1452.npy
# ./test001.png    ./test533.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1451, dtype: object
# 1638.npy
# ./test001.png    ./test719.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1637, dtype: object
# 0752.npy
# ./test001.png    ./test753.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 751, dtype: object
# 0385.npy
# ./test001.png    ./test386.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 384, dtype: object
# 1522.npy
# ./test001.png    ./test603.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 1521, dtype: object
# 1061.npy
# ./test001.png    ./test142.png
# -1                           1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1060, dtype: object
# 1518.npy
# ./test001.png    ./test599.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1517, dtype: object
# 0171.npy
# ./test001.png    ./test172.png
# -1                          -1
# -1.1                         1
# -1.2                         1
# -1.3                        -1
# Name: 170, dtype: object
# 1161.npy
# ./test001.png    ./test242.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1160, dtype: object
# 0437.npy
# ./test001.png    ./test438.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 436, dtype: object
# 0312.npy
# ./test001.png    ./test313.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 311, dtype: object
# 1234.npy
# ./test001.png    ./test315.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1233, dtype: object
# 0368.npy
# ./test001.png    ./test369.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 367, dtype: object
# 0644.npy
# ./test001.png    ./test645.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 643, dtype: object
# 0339.npy
# ./test001.png    ./test340.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 338, dtype: object
# 1441.npy
# ./test001.png    ./test522.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 1440, dtype: object
# 0208.npy
# ./test001.png    ./test209.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 207, dtype: object
# 1174.npy
# ./test001.png    ./test255.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1173, dtype: object
# 1795.npy
# ./test001.png    ./test876.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1794, dtype: object
# 0534.npy
# ./test001.png    ./test535.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 533, dtype: object
# 1565.npy
# ./test001.png    ./test646.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1564, dtype: object
# 0937.npy
# ./test001.png    ./test018.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 936, dtype: object
# 1641.npy
# ./test001.png    ./test722.png
# -1                          -1
# -1.1                         1
# -1.2                         1
# -1.3                        -1
# Name: 1640, dtype: object
# 0550.npy
# ./test001.png    ./test551.png
# -1                           1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 549, dtype: object
# 0678.npy
# ./test001.png    ./test679.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 677, dtype: object
# 1687.npy
# ./test001.png    ./test768.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1686, dtype: object
# 1789.npy
# ./test001.png    ./test870.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1788, dtype: object
# 1098.npy
# ./test001.png    ./test179.png
# -1                          -1
# -1.1                         1
# -1.2                        -1
# -1.3                        -1
# Name: 1097, dtype: object
# 0153.npy
# ./test001.png    ./test154.png
# -1                          -1
# -1.1                         1
# -1.2                        -1
# -1.3                        -1
# Name: 152, dtype: object
# 1828.npy
# ./test001.png    ./test909.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 1827, dtype: object
# 1789.npy
# ./test001.png    ./test870.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1788, dtype: object
# 0986.npy
# ./test001.png    ./test067.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 985, dtype: object
# 1103.npy
# ./test001.png    ./test184.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 1102, dtype: object
# 0849.npy
# ./test001.png    ./test850.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 848, dtype: object
# 1309.npy
# ./test001.png    ./test390.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 1308, dtype: object
# 0486.npy
# ./test001.png    ./test487.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 485, dtype: object
# 0809.npy
# ./test001.png    ./test810.png
# -1                          -1
# -1.1                         1
# -1.2                         1
# -1.3                        -1
# Name: 808, dtype: object
# 1259.npy
# ./test001.png    ./test340.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 1258, dtype: object
# 0777.npy
# ./test001.png    ./test778.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 776, dtype: object
# 0221.npy
# ./test001.png    ./test222.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 220, dtype: object
# 1259.npy
# ./test001.png    ./test340.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 1258, dtype: object
# 0624.npy
# ./test001.png    ./test625.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 623, dtype: object
# 0448.npy
# ./test001.png    ./test449.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 447, dtype: object
# 0754.npy
# ./test001.png    ./test755.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 753, dtype: object
# 0139.npy
# ./test001.png    ./test140.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 138, dtype: object
# 0632.npy
# ./test001.png    ./test633.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 631, dtype: object
# 1817.npy
# ./test001.png    ./test898.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1816, dtype: object
# 1486.npy
# ./test001.png    ./test567.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1485, dtype: object
# 0666.npy
# ./test001.png    ./test667.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 665, dtype: object
# 0576.npy
# ./test001.png    ./test577.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 575, dtype: object
# 0244.npy
# ./test001.png    ./test245.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 243, dtype: object
# 1628.npy
# ./test001.png    ./test709.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1627, dtype: object
# 1018.npy
# ./test001.png    ./test099.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1017, dtype: object
# 1752.npy
# ./test001.png    ./test833.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1751, dtype: object
# 0149.npy
# ./test001.png    ./test150.png
# -1                          -1
# -1.1                         1
# -1.2                         1
# -1.3                        -1
# Name: 148, dtype: object
# 1210.npy
# ./test001.png    ./test291.png
# -1                          -1
# -1.1                         1
# -1.2                         1
# -1.3                        -1
# Name: 1209, dtype: object
# 0550.npy
# ./test001.png    ./test551.png
# -1                           1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 549, dtype: object
# 0427.npy
# ./test001.png    ./test428.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 426, dtype: object
# epoch:1, d_loss:-656.7973022460938, g_loss: -1379.9864501953125
# 0504.npy
# ./test001.png    ./test505.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 503, dtype: object
# 0306.npy
# ./test001.png    ./test307.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 305, dtype: object
# 0664.npy
# ./test001.png    ./test665.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 663, dtype: object
# 0077.npy
# ./test001.png    ./test078.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 76, dtype: object
# 1116.npy
# ./test001.png    ./test197.png
# -1                          -1
# -1.1                         1
# -1.2                         1
# -1.3                        -1
# Name: 1115, dtype: object
# 1005.npy
# ./test001.png    ./test086.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1004, dtype: object
# 1066.npy
# ./test001.png    ./test147.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1065, dtype: object
# 1623.npy
# ./test001.png    ./test704.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1622, dtype: object
# 0283.npy
# ./test001.png    ./test284.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 282, dtype: object
# 0196.npy
# ./test001.png    ./test197.png
# -1                          -1
# -1.1                         1
# -1.2                         1
# -1.3                        -1
# Name: 195, dtype: object
# 1434.npy
# ./test001.png    ./test515.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1433, dtype: object
# 0367.npy
# ./test001.png    ./test368.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 366, dtype: object
# 1799.npy
# ./test001.png    ./test880.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1798, dtype: object
# 0890.npy
# ./test001.png    ./test891.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 889, dtype: object
# 1046.npy
# ./test001.png    ./test127.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 1045, dtype: object
# 0758.npy
# ./test001.png    ./test759.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 757, dtype: object
# 1642.npy
# ./test001.png    ./test723.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1641, dtype: object
# 0449.npy
# ./test001.png    ./test450.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 448, dtype: object
# 1761.npy
# ./test001.png    ./test842.png
# -1                          -1
# -1.1                         1
# -1.2                        -1
# -1.3                        -1
# Name: 1760, dtype: object
# 1231.npy
# ./test001.png    ./test312.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1230, dtype: object
# 0738.npy
# ./test001.png    ./test739.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 737, dtype: object
# 0523.npy
# ./test001.png    ./test524.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 522, dtype: object
# 0332.npy
# ./test001.png    ./test333.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 331, dtype: object
# 0535.npy
# ./test001.png    ./test536.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 534, dtype: object
# 0292.npy
# ./test001.png    ./test293.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 291, dtype: object
# 1715.npy
# ./test001.png    ./test796.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1714, dtype: object
# 0490.npy
# ./test001.png    ./test491.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 489, dtype: object
# 0352.npy
# ./test001.png    ./test353.png
# -1                           1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 351, dtype: object
# 1198.npy
# ./test001.png    ./test279.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 1197, dtype: object
# 0302.npy
# ./test001.png    ./test303.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 301, dtype: object
# 1261.npy
# ./test001.png    ./test342.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 1260, dtype: object
# 0479.npy
# ./test001.png    ./test480.png
# -1                           1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 478, dtype: object
# 0841.npy
# ./test001.png    ./test842.png
# -1                          -1
# -1.1                         1
# -1.2                        -1
# -1.3                        -1
# Name: 840, dtype: object
# 0747.npy
# ./test001.png    ./test748.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 746, dtype: object
# 0851.npy
# ./test001.png    ./test852.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 850, dtype: object
# 0236.npy
# ./test001.png    ./test237.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 235, dtype: object
# 0574.npy
# ./test001.png    ./test575.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 573, dtype: object
# 1432.npy
# ./test001.png    ./test513.png
# -1                          -1
# -1.1                         1
# -1.2                         1
# -1.3                        -1
# Name: 1431, dtype: object
# 0400.npy
# ./test001.png    ./test401.png
# -1                           1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 399, dtype: object
# 0877.npy
# ./test001.png    ./test878.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 876, dtype: object
# 0980.npy
# ./test001.png    ./test061.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 979, dtype: object
# 1399.npy
# ./test001.png    ./test480.png
# -1                           1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1398, dtype: object
# 1117.npy
# ./test001.png    ./test198.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1116, dtype: object
# 0908.npy
# ./test001.png    ./test909.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 907, dtype: object
# 1511.npy
# ./test001.png    ./test592.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 1510, dtype: object
# 0768.npy
# ./test001.png    ./test769.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 767, dtype: object
# 0989.npy
# ./test001.png    ./test070.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 988, dtype: object
# 1696.npy
# ./test001.png    ./test777.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1695, dtype: object
# 0293.npy
# ./test001.png    ./test294.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 292, dtype: object
# 0015.npy
# ./test001.png    ./test016.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 14, dtype: object
# 1610.npy
# ./test001.png    ./test691.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1609, dtype: object
# 1582.npy
# ./test001.png    ./test663.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1581, dtype: object
# 0824.npy
# ./test001.png    ./test825.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 823, dtype: object
# 0124.npy
# ./test001.png    ./test125.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 123, dtype: object
# 0457.npy
# ./test001.png    ./test458.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 456, dtype: object
# 0668.npy
# ./test001.png    ./test669.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 667, dtype: object
# 0161.npy
# ./test001.png    ./test162.png
# -1                          -1
# -1.1                         1
# -1.2                         1
# -1.3                        -1
# Name: 160, dtype: object
# 1612.npy
# ./test001.png    ./test693.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1611, dtype: object
# 1694.npy
# ./test001.png    ./test775.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1693, dtype: object
# 1448.npy
# ./test001.png    ./test529.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1447, dtype: object
# 1173.npy
# ./test001.png    ./test254.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1172, dtype: object
# 0312.npy
# ./test001.png    ./test313.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 311, dtype: object
# 1189.npy
# ./test001.png    ./test270.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1188, dtype: object
# 1163.npy
# ./test001.png    ./test244.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1162, dtype: object
# 1194.npy
# ./test001.png    ./test275.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1193, dtype: object
# 1222.npy
# ./test001.png    ./test303.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1221, dtype: object
# 0765.npy
# ./test001.png    ./test766.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 764, dtype: object
# 1274.npy
# ./test001.png    ./test355.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 1273, dtype: object
# 1074.npy
# ./test001.png    ./test155.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1073, dtype: object
# 0415.npy
# ./test001.png    ./test416.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 414, dtype: object
# 0821.npy
# ./test001.png    ./test822.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 820, dtype: object
# 0446.npy
# ./test001.png    ./test447.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 445, dtype: object
# 1662.npy
# ./test001.png    ./test743.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1661, dtype: object
# 0263.npy
# ./test001.png    ./test264.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 262, dtype: object
# 0551.npy
# ./test001.png    ./test552.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 550, dtype: object
# 0423.npy
# ./test001.png    ./test424.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 422, dtype: object
# 1760.npy
# ./test001.png    ./test841.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1759, dtype: object
# 0144.npy
# ./test001.png    ./test145.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 143, dtype: object
# 0019.npy
# ./test001.png    ./test020.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 18, dtype: object
# 1159.npy
# ./test001.png    ./test240.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1158, dtype: object
# epoch:2, d_loss:-30619.357421875, g_loss: -65750.859375
# 0905.npy
# ./test001.png    ./test906.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 904, dtype: object
# 0525.npy
# ./test001.png    ./test526.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 524, dtype: object
# 0308.npy
# ./test001.png    ./test309.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 307, dtype: object
# 0758.npy
# ./test001.png    ./test759.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 757, dtype: object
# 1495.npy
# ./test001.png    ./test576.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1494, dtype: object
# 1787.npy
# ./test001.png    ./test868.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1786, dtype: object
# 0728.npy
# ./test001.png    ./test729.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 727, dtype: object
# 0481.npy
# ./test001.png    ./test482.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 480, dtype: object
# 0137.npy
# ./test001.png    ./test138.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 136, dtype: object
# 1105.npy
# ./test001.png    ./test186.png
# -1                          -1
# -1.1                         1
# -1.2                        -1
# -1.3                        -1
# Name: 1104, dtype: object
# 1463.npy
# ./test001.png    ./test544.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1462, dtype: object
# 1522.npy
# ...
# Name: 1286, dtype: object
# 1183.npy
# ./test001.png    ./test264.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1182, dtype: object
# 1457.npy
# ./test001.png    ./test538.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1456, dtype: object
# 0371.npy
# ./test001.png    ./test372.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 370, dtype: object
# 0575.npy
# ./test001.png    ./test576.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 574, dtype: object
# 0235.npy
# ./test001.png    ./test236.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 234, dtype: object
# 0154.npy
# ./test001.png    ./test155.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 153, dtype: object
# 0976.npy
# ./test001.png    ./test057.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 975, dtype: object
# 0783.npy
# ./test001.png    ./test784.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 782, dtype: object
# 0931.npy
# ./test001.png    ./test012.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 930, dtype: object
# 0620.npy
# ./test001.png    ./test621.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 619, dtype: object
# 1432.npy
# ./test001.png    ./test513.png
# -1                          -1
# -1.1                         1
# -1.2                         1
# -1.3                        -1
# Name: 1431, dtype: object
# 0437.npy
# ./test001.png    ./test438.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 436, dtype: object
# 0348.npy
# ./test001.png    ./test349.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 347, dtype: object
# 0134.npy
# ./test001.png    ./test135.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 133, dtype: object
# 0540.npy
# ./test001.png    ./test541.png
# -1                           1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 539, dtype: object
# 1343.npy
# ./test001.png    ./test424.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1342, dtype: object
# 0033.npy
# ./test001.png    ./test034.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 32, dtype: object
# 1566.npy
# ./test001.png    ./test647.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1565, dtype: object
# 0504.npy
# ./test001.png    ./test505.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 503, dtype: object
# 1350.npy
# ./test001.png    ./test431.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1349, dtype: object
# 0377.npy
# ./test001.png    ./test378.png
# -1                           1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 376, dtype: object
# 1815.npy
# ./test001.png    ./test896.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1814, dtype: object
# 1065.npy
# ./test001.png    ./test146.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1064, dtype: object
# 1098.npy
# ./test001.png    ./test179.png
# -1                          -1
# -1.1                         1
# -1.2                        -1
# -1.3                        -1
# Name: 1097, dtype: object
# 0876.npy
# ./test001.png    ./test877.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 875, dtype: object
# 1793.npy
# ./test001.png    ./test874.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1792, dtype: object
# 0299.npy
# ./test001.png    ./test300.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 298, dtype: object
# 1764.npy
# ./test001.png    ./test845.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1763, dtype: object
# 1071.npy
# ./test001.png    ./test152.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1070, dtype: object
# 1258.npy
# ./test001.png    ./test339.png
# -1                           1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1257, dtype: object
# 1382.npy
# ./test001.png    ./test463.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1381, dtype: object
# 0070.npy
# ./test001.png    ./test071.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 69, dtype: object
# 0506.npy
# ./test001.png    ./test507.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 505, dtype: object
# 0283.npy
# ./test001.png    ./test284.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 282, dtype: object
# 1103.npy
# ./test001.png    ./test184.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 1102, dtype: object
# 0374.npy
# ./test001.png    ./test375.png
# -1                           1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 373, dtype: object
# epoch:7, d_loss:-116576.53125, g_loss: -94712.03125
# 0729.npy
# ./test001.png    ./test730.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 728, dtype: object
# 1467.npy
# ./test001.png    ./test548.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1466, dtype: object
# 1514.npy
# ./test001.png    ./test595.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1513, dtype: object
# 1824.npy
# ./test001.png    ./test905.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1823, dtype: object
# 0512.npy
# ./test001.png    ./test513.png
# -1                          -1
# -1.1                         1
# -1.2                         1
# -1.3                        -1
# Name: 511, dtype: object
# 1050.npy
# ./test001.png    ./test131.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1049, dtype: object
# 0025.npy
# ./test001.png    ./test026.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 24, dtype: object
# 0604.npy
# ./test001.png    ./test605.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 603, dtype: object
# 0510.npy
# ./test001.png    ./test511.png
# -1                           1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 509, dtype: object
# 0357.npy
# ./test001.png    ./test358.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 356, dtype: object
# 1657.npy
# ./test001.png    ./test738.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1656, dtype: object
# 0254.npy
# ./test001.png    ./test255.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 253, dtype: object
# 1644.npy
# ./test001.png    ./test725.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1643, dtype: object
# 0039.npy
# ./test001.png    ./test040.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 38, dtype: object
# 0742.npy
# ./test001.png    ./test743.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 741, dtype: object
# 0073.npy
# ./test001.png    ./test074.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 72, dtype: object
# 0207.npy
# ./test001.png    ./test208.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 206, dtype: object
# 0546.npy
# ./test001.png    ./test547.png
# -1                          -1
# -1.1                         1
# -1.2                         1
# -1.3                        -1
# Name: 545, dtype: object
# 0111.npy
# ./test001.png    ./test112.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 110, dtype: object
# 1514.npy
# ./test001.png    ./test595.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1513, dtype: object
# 0030.npy
# ./test001.png    ./test031.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 29, dtype: object
# 0257.npy
# ./test001.png    ./test258.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 256, dtype: object
# 1349.npy
# ./test001.png    ./test430.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1348, dtype: object
# 0527.npy
# ./test001.png    ./test528.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 526, dtype: object
# 1399.npy
# ./test001.png    ./test480.png
# -1                           1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1398, dtype: object
# 0599.npy
# ./test001.png    ./test600.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 598, dtype: object
# 1198.npy
# ./test001.png    ./test279.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 1197, dtype: object
# 1577.npy
# ./test001.png    ./test658.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1576, dtype: object
# 0654.npy
# ./test001.png    ./test655.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 653, dtype: object
# 1366.npy
# ./test001.png    ./test447.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1365, dtype: object
# 1702.npy
# ./test001.png    ./test783.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1701, dtype: object
# 0548.npy
# ./test001.png    ./test549.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 547, dtype: object
# 1204.npy
# ./test001.png    ./test285.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1203, dtype: object
# 0336.npy
# ./test001.png    ./test337.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 335, dtype: object
# 0336.npy
# ./test001.png    ./test337.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 335, dtype: object
# 0978.npy
# ./test001.png    ./test059.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 977, dtype: object
# 1182.npy
# ./test001.png    ./test263.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                         1
# Name: 1181, dtype: object
# 1626.npy
# ./test001.png    ./test707.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1625, dtype: object
# 1748.npy
# ./test001.png    ./test829.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1747, dtype: object
# 1107.npy
# ./test001.png    ./test188.png
# -1                          -1
# -1.1                         1
# -1.2                         1
# -1.3                        -1
# Name: 1106, dtype: object
# 0648.npy
# ./test001.png    ./test649.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 647, dtype: object
# 1697.npy
# ./test001.png    ./test778.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 1696, dtype: object
# 0329.npy
# ./test001.png    ./test330.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 328, dtype: object
# 1567.npy
# ./test001.png    ./test648.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                         1
# Name: 1566, dtype: object
# 0964.npy
# ./test001.png    ./test045.png
# -1                          -1
# -1.1                        -1
# -1.2                         1
# -1.3                        -1
# Name: 963, dtype: object
# 1765.npy
# ./test001.png    ./test846.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 1764, dtype: object
# 0499.npy
# ./test001.png    ./test500.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 498, dtype: object
# 0671.npy
# ./test001.png    ./test672.png
# -1                          -1
# -1.1                        -1
# -1.2                        -1
# -1.3                        -1
# Name: 670, dtype: object

# %% [markdown]
# ######
